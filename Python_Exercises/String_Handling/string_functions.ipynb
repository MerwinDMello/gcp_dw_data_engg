# %%
# Replace Example
lob = "edwhr"
lob_suffix = lob.replace("edw","")
print(lob_suffix)

# %%
dataset = "edwhr"
if "view" not in dataset.lower():
    print("Views not found in dataset", dataset)

# %%
field = "9"
print(field.zfill(5))
print(field.rjust(5,'x'))
print(field.ljust(5,'x'))

# %%
value = "Yes"
value_string = str(value)
print(value_string)

# %%
string_value = "Caterpillar"
print(string_value[0:3]) # Cat
print(string_value[1:4]) # ate
print(string_value[-6:]) # pillar
print(string_value[-6:-2]) # pill
# Out:
# Cat
# ate
# pillar
# pill

# %%
string_value = "956"
string_value[-3:]
# Out:
# '956'

# %%
name = '"Merwin D"Mello"'
print(name)
stripped_name = name.strip('"')
print(stripped_name)
padded_name = stripped_name.center(len(stripped_name) + 2, '"')
print(padded_name)
# Out:
# "Merwin D"Mello"
# Merwin D"Mello
# "Merwin D"Mello"

# %%
string_field = 'D"Mello, Merwin'
delimiter = ','
quote_char = '"'
search_value = '"'
replace_value = "`"

print(string_field)

if delimiter in string_field:
    string_field = string_field.center(len(string_field) + 2, quote_char)

print(string_field)

# Remove padded quotes from string field if search value and quote character is the same 
if search_value == quote_char:
    string_field = string_field.strip(quote_char)

print(string_field)

string_field = string_field.replace(search_value, replace_value)

# Add back the quotes if search value and quote character is the same and delimiter is present
if search_value == quote_char and delimiter in string_field:
    string_field = string_field.center(len(string_field) + 2, quote_char)

print(string_field)
# Out:
# D"Mello, Merwin
# "D"Mello, Merwin"
# D"Mello, Merwin
# "D`Mello, Merwin"
