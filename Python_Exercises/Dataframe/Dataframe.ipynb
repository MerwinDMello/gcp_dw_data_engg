# %%
import pandas as pd

# %%
df = pd.DataFrame({'stack': ['A', 'B', 'F'], 'count': [12345, 11111, 54321]})

rec_list = []
for idx, row in df.iterrows():
    rec_dict_item = {"stack":row['stack'], "count":row['count']}
    rec_list.append(rec_dict_item)
print(rec_list)
