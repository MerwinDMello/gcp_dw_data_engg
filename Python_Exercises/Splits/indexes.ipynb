# %%
# Get File Name from Path
object_path = "edwhrdata/srcfiles/enwisen/HCA_CM5Tickets_20221207.txt.pgp"
object_name = object_path[object_path.rindex("/")+1:]
print(object_name)

# %%
# Remove Date Marker
FileName = "Job_Information_20230121.txt.pgp"
FileParts = FileName.split('.',1)
FileName = FileParts[0].rsplit("_",1)
new_file = FileName[0]+'.'+FileParts[1]
print(new_file)
