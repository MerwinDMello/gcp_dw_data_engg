# %%
import json

json_string_raw = "{'id': '2025-10-20_02_49_04-10167309323696874449', 'projectId': 'hca-hin-dev-proc-parallon', 'name': 'jdbc-to-bq-psc-wave-other4-ecw-refproviderlawson-20251015-e48b719d', 'currentState': 'JOB_STATE_DONE', 'currentStateTime': '2025-10-20T09:54:52.016533Z', 'createTime': '2025-10-20T09:49:05.425444Z', 'location': 'us-east4', 'startTime': '2025-10-20T09:49:05.425444Z'}"

json_string_data = json_string_raw.replace("'",'"')

json_data = json.loads(json_string_data)

print(json_data["name"])
# Out:
# jdbc-to-bq-psc-wave-other4-ecw-refproviderlawson-20251015-e48b719d
