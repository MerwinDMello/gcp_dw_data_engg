# %%
import paramiko
ssh_client=paramiko.SSHClient()
ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh_client.connect(hostname='naetlp11.unix.medcity.net',username='khu9683',password='Mer82@dme')

# %%
bteqs = [
    'HDW_Taleo_RECRTMENT_REQUISTN_WRK.sql',
    'HDW_TALEO_RECRTMENT_REQUISTN.sql'
]

# %%
ftp_client=ssh_client.open_sftp()
# print(ftp_client.listdir('.')) 
# stdin,stdout,stderr=ssh_client.exec_command("cd..")
# print(stdout.readlines())
# print(stderr.readlines())
# print(ftp_client.listdir('/etl/jfmd/EDWHR/Scripts/')) 

for bteq in bteqs:
    remote_location = '/etl/jfmd/EDWHR/Scripts/' + bteq
    file_location = 'C:\\Merwin\\LOB\\EDWHR\\Taleo\\BTEQ\\' + bteq
    ftp_client.get(remote_location, file_location)
ftp_client.close()
